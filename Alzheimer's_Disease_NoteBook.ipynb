# %% [markdown]
# <a href="https://colab.research.google.com/github/Knguyen351/Data-Mining-Project/blob/main/Alzheimer's_Disease_NoteBook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Alzheimer's_Disease_Kevin_Nguyen

# Basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, cohen_kappa_score
import warnings
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, cohen_kappa_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

warnings.filterwarnings("ignore")

# Import Dataset
url = "https://raw.githubusercontent.com/Knguyen351/Data-Mining-Project/refs/heads/main/alzheimers_disease_data.csv"
df = pd.read_csv(url)


df.head(15)
# Out:
#     PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0        4751   73       0          0               2  22.927749        0
# 1        4752   89       0          0               0  26.827681        0
# 2        4753   73       0          3               1  17.795882        0
# 3        4754   74       1          0               1  33.800817        1
# 4        4755   89       0          0               0  20.716974        0
# 5        4756   86       1          1               1  30.626886        0
# 6        4757   68       0          3               2  38.387622        1
# 7        4758   75       0          0               1  18.776009        0
# 8        4759   72       1          1               0  27.833188        0
# 9        4760   87       0          0               0  35.456302        1
# 10       4761   89       0          3               1  39.463034        0
# 11       4762   78       0          0               2  22.463383        1
# ...

# %%
# Preparing Data

display(df.describe(include='all').T)
# Out:
#                             count unique        top  freq        mean  \
# PatientID                  2149.0    NaN        NaN   NaN      5825.0
# Age                        2149.0    NaN        NaN   NaN   74.908795
# Gender                     2149.0    NaN        NaN   NaN    0.506282
# Ethnicity                  2149.0    NaN        NaN   NaN    0.697534
# EducationLevel             2149.0    NaN        NaN   NaN    1.286645
# BMI                        2149.0    NaN        NaN   NaN   27.655697
# Smoking                    2149.0    NaN        NaN   NaN    0.288506
# AlcoholConsumption         2149.0    NaN        NaN   NaN   10.039442
# PhysicalActivity           2149.0    NaN        NaN   NaN    4.920202
# DietQuality                2149.0    NaN        NaN   NaN    4.993138
# SleepQuality               2149.0    NaN        NaN   NaN    7.051081
# FamilyHistoryAlzheimers    2149.0    NaN        NaN   NaN     0.25221
# ...

# %%
#Random Forest Model

X = df.drop("Diagnosis", axis=1)
y = df["Diagnosis"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=123
)


numeric_cols = ["Age", "AlcoholConsumption"]
categorical_cols = ["Gender", "Ethnicity", "DoctorInCharge"]


numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median"))
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_cols),
        ("cat", categorical_transformer, categorical_cols)
    ]
)



rf_model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("model", RandomForestClassifier(random_state=123))
])

rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred))

print("Cohen's Kappa:", round(cohen_kappa_score(y_test, y_pred), 4))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.73      0.68       281
#            1       0.32      0.24      0.27       149
#
#     accuracy                           0.56       430
#    macro avg       0.48      0.48      0.48       430
# weighted avg       0.53      0.56      0.54       430
#
# Cohen's Kappa: -0.0344

# %%
# Missing values summary
missing_values = df.isnull().sum().sort_values(ascending=False)
missing_values = missing_values[missing_values > 0]
display(missing_values)
# Out:
# Series([], dtype: int64)

# %%
# Confusion Matrix


y_pred = rf_model.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(ax=ax)
ax.set_title("Confusion Matrix")
plt.show()
